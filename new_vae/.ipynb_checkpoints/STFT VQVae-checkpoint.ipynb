# %%
import tensorflow as tf
import tensorflow_io as tfio
from models.vqvae import *
from IPython import display

import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import tensorflow_probability as tfp
import time
from loader import *

from IPython.display import Audio 
import librosa
import librosa.display
# Out:
# /home/jerms/.pyenv/versions/3.8.12/lib/python3.8/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
train_dataset, test_dataset = get_training_set()
# Out:
# 2021-10-06 07:04:00.238939: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 07:04:00.383774: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 07:04:00.384419: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 07:04:00.387946: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-06 07:04:00.388433: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 07:04:00.389110: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 07:04:00.389719: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 07:04:01.749561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 07:04:01.750241: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 07:04:01.750847: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from
# loading spectrogram
# loading spectrogram
#  SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 07:04:01.751389: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13803 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %%
vqvae_trainer = VQVAETrainer(latent_dim=128, num_embeddings=128)
vqvae_trainer.load_weights("/home/jerms/daniil/new_vae/saved_models/vqvae_run_stft_1")
vqvae_trainer.compile(optimizer=keras.optimizers.Adam())

# %%
def get_predictions(model, test_samples):
    predictions = model.vqvae(test_samples)
    return predictions

# %%
for test_batch in test_dataset.take(1):
    test_sample = test_batch[0][0:16, :, :, :]

# %%
preds = get_predictions(vqvae_trainer, test_sample)

# %%
preds
# Out:
# <tf.Tensor: shape=(16, 1024, 88, 1), dtype=float32, numpy=
# array([[[[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         ...,
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]]],
#
#
#        [[[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         ...,
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]]],
#
#
#        [[[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         ...,
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]]],
#
#
#        ...,
#
#
#        [[[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         ...,
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]]],
#
#
#        [[[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         ...,
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]]],
#
#
#        [[[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         ...,
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]]]], dtype=float32)>

# %%
audio_index = 0

# %%
stft_ = test_sample[audio_index]
real_comp, imag_comp = stft_[:, :, 0].numpy(), stft_[:, :, 1].numpy()
stft = real_comp + imag_comp * 1j

# %%
stft_.shape
# Out:
# TensorShape([1024, 88, 2])

# %%
audio = librosa.istft(stft)

# %%
len(audio)
# Out:
# 44457

# %%
Audio(audio, rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Good Original Audio

# %% [markdown]
# # Reconstructed

# %%
preds
# Out:
# <tf.Tensor: shape=(16, 1024, 88, 1), dtype=float32, numpy=
# array([[[[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         ...,
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]]],
#
#
#        [[[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         ...,
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]]],
#
#
#        [[[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         ...,
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]]],
#
#
#        ...,
#
#
#        [[[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         ...,
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]]],
#
#
#        [[[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         ...,
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]]],
#
#
#        [[[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         ...,
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]],
#
#         [[4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05],
#          ...,
#          [4.691004e-05],
#          [4.691004e-05],
#          [4.691004e-05]]]], dtype=float32)>

# %%
reconstructed_stft = preds[audio_index]
real_comp_, imag_comp_ = reconstructed_stft[:,:,0].numpy(), reconstructed_stft[:,:,1].numpy()
stft_ = real_comp_ + imag_comp_ * 1j
# Out:
# 2021-10-06 03:25:55.439264: W tensorflow/core/framework/op_kernel.cc:1692] OP_REQUIRES failed at strided_slice_op.cc:108 : Invalid argument: slice index 1 of dimension 2 out of bounds.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /tmp/ipykernel_9971/1049099677.py in <module>
#       1 reconstructed_stft = preds[audio_index]
# ----> 2 real_comp_, imag_comp_ = reconstructed_stft[:,:,0].numpy(), reconstructed_stft[:,:,1].numpy()
#       3 stft_ = real_comp_ + imag_comp_ * 1j
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#    1039       var_empty = constant([], dtype=dtypes.int32)
#    1040       packed_begin = packed_end = packed_strides = var_empty
# -> 1041     return strided_slice(
#    1042         tensor,
#    1043         packed_begin,
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#    1212     strides = ones_like(begin)
#    1213
# -> 1214   op = gen_array_ops.strided_slice(
#    1215       input=input_,
#    1216       begin=begin,
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#   10509       return _result
#   10510     except _core._NotOkStatusException as e:
# > 10511       _ops.raise_from_not_ok_status(e, name)
#   10512     except _core._FallbackException:
#   10513       pass
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6939   message = e.message + (" name: " + name if name is not None else "")
#    6940   # pylint: disable=protected-access
# -> 6941   six.raise_from(core._status_to_exception(e.code, message), None)
#    6942   # pylint: enable=protected-access
#    6943
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: slice index 1 of dimension 2 out of bounds. [Op:StridedSlice] name: strided_slice/

# %%
encoder = vqvae_trainer.vqvae.get_encoder()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_9971/42924028.py in <module>
# ----> 1 encoder = vqvae_trainer.vqvae.get_encoder()
#
# AttributeError: 'Functional' object has no attribute 'get_encoder'

# %%
def get_encoder(latent_dim=128):
    encoder_inputs = keras.Input(shape=(1024, 88, 2))
    x = layers.Conv2D(32, 3, activation="relu", strides=(2,2), padding="same")(
        encoder_inputs
    )
    x = layers.Conv2D(64, 3, activation="relu", strides=(2,2), padding="same")(x)
    x = layers.Conv2D(128, 3, activation="relu", strides=(2,2), padding="same")(x)
    x = layers.Conv2D(256, 3, activation="relu", strides=(2,1), padding="same")(x)
    x = layers.Conv2D(512, 3, activation="relu", strides=(2,1), padding="same")(x)
    
    encoder_outputs = layers.Conv2D(latent_dim, 1, padding="same")(x)
    return keras.Model(encoder_inputs, encoder_outputs, name="encoder")

def get_decoder(latent_dim=128):
    latent_inputs = keras.Input(shape=get_encoder().output.shape[1:])
    x = layers.Conv2DTranspose(512, 3, activation="relu", strides=[2,1], padding="same")(
        latent_inputs
    )
    x = layers.Conv2DTranspose(256, 3, activation="relu", strides=[2,1], padding="same")(x)
    x = layers.Conv2DTranspose(128, 3, activation="relu", strides=2, padding="same")(x)
    x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
    x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
    decoder_outputs = layers.Conv2DTranspose(2, 3, padding="same")(x)
    return keras.Model(latent_inputs, decoder_outputs, name="decoder")

# %%
encoder = get_encoder()
decoder = get_decoder()

# %%
for layer in encoder.layers:
    print(layer.output_shape)
# Out:
# [(None, 1024, 88, 2)]
# (None, 512, 44, 32)
# (None, 256, 22, 64)
# (None, 128, 11, 128)
# (None, 64, 11, 256)
# (None, 32, 11, 512)
# (None, 32, 11, 128)

# %%
for layer in decoder.layers:
    print(layer.output_shape)
# Out:
# [(None, 32, 11, 128)]
# (None, 64, 11, 512)
# (None, 128, 11, 256)
# (None, 256, 22, 128)
# (None, 512, 44, 64)
# (None, 1024, 88, 32)
# (None, 1024, 88, 2)
