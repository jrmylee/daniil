# %%
import sys
  
# setting path
sys.path.append('../')
# importing
import librosa
import librosa.display
from IPython.display import Audio
from models.vqvae2 import *
from utils.kapre_helpers import *
from utils.helpers import load_test_data
from utils.echo import convolve_with_room
import soundfile

# %%
vqvae_trainer = VQVAETrainer(latent_dim=128, num_embeddings=128)
vqvae_trainer.load_weights("../../new_vae/saved_models/recon_02")
vqvae_trainer.compile(optimizer=keras.optimizers.Adam())
# Out:
# Metal device set to: Apple M1 Pro
# 2021-12-13 14:48:53.758664: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-12-13 14:48:53.758782: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
widmung, sr = librosa.load("/Users/llewyn/Documents/recordings/widmung-clean.m4a", sr=44100)
ir, sr = librosa.load("../samples/irs/ir1.aif", sr=44100)
# Out:
# /Users/llewyn/miniforge3/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
convolved = convolve_with_room(widmung, ir)

# %%
chunked_dec, chunked_ang = kapre_stft(widmung)

# %%
output = vqvae_trainer.vqvae(chunked_dec)

# %%
reconstructed = reconstruct_audio(chunked_dec, chunked_ang, 1.)

# %%
soundfile.write('../samples/test2.wav', librosa.util.normalize(reconstructed), 44100)
soundfile.write('../samples/test2_og.wav', librosa.util.normalize(widmung), 44100)
soundfile.write('../samples/test2_conv.wav', librosa.util.normalize(convolved), 44100)

# %%
S.shape
# Out:
# (1025, 87)

# %%
chunked_dec[0].shape
# Out:
# (88, 1024, 1)

# %%
S = np.abs(librosa.stft((widmung[44100 * 0 : 44100 * 1])))
S_db = librosa.amplitude_to_db(S, ref=np.max)
S_ = librosa.db_to_amplitude(S_db)
y = librosa.istft(S_, )

# %%
plt.figure()
librosa.display.specshow(S_db)
plt.colorbar()

# %%
S_db_ = S_db_kapre.numpy().squeeze(0).squeeze(2)
S_db_ = np.swapaxes(S_db_, 0, 1)

# %%
S_db_.shape
# Out:
# (1025, 86)

# %%
plt.figure()
librosa.display.specshow(S_db_)
plt.colorbar()

# %%
print(np.max(S_db), np.min(S_db))
# Out:
# 0.0 -80.0

# %%
print(np.max(S_db_kapre.numpy()), np.min(S_db_kapre.numpy()))
# Out:
# 7.6293945e-06 -79.99999

# %%
from kapre.time_frequency import STFT, InverseSTFT, Magnitude, Phase, MagnitudeToDecibel

def kapre(x, ref=500):
    x = np.expand_dims(x, 0)
    x = np.expand_dims(x, 2)
    STFT_Layer = STFT(n_fft=2048, win_length=2048, hop_length=512,
                   window_name=None, pad_end=False, pad_begin=True,
                   input_data_format='channels_last', output_data_format='channels_last',
                   input_shape=(len(x), 1))
    ISTFT_Layer = InverseSTFT(n_fft=2048, hop_length=512, 
            input_shape=(88, 1024, 1))
    Mag_Layer = Magnitude()
    Phase_Layer = Phase()
    
    stft = STFT_Layer(x)
    mag = Mag_Layer(stft)
    
    Decibel_Layer = MagnitudeToDecibel(ref_value=tf.math.reduce_max(mag) ** 2, amin=1e-5 ** 2)
    dec = Decibel_Layer(tf.math.square(mag))
    return dec

# %%
S_db_kapre = kapre(librosa.util.normalize(widmung[0 : 44100]))
